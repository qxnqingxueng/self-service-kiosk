# %% [markdown]
# <a href="https://colab.research.google.com/github/qxnqingxueng/self-service-kiosk/blob/main/self_service_kiosk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Program scenario**

# %% [markdown]
# Many customers aim to purchase various types of cookies and cakes for their festivities. To simplify the sales process, a program is needed to recognise whether you are staff or customer and manage log in or sign up process for staff and customer. In addition, we have designed 2 cases for staff and customer flexibility. For staff, the program manage to check and edit the inventory, add new stock as well. For customer, the program manage to check different types of cookies and cakes menu, facilitate customer orders payment and apply discounts. In a nutshell, a kiosk for selling cookies and cakes could cater to a different customer's preferences and address the staffing shortage.
#
# We are going to discuss the essence of use cases and scenarios and explore the significance of scenario could be faced by users.

# %% [markdown]
# ### **First Scenario : User Log in or Sign Up**
#
#   We begin by identifying a fundamental use case: "User Login or Sign Up". This use case encapsulates the primary interaction between user and the system, which is the starting point for using the kiosk.
#
# * **Scenario 1: User log in as either staff or customer successfully**
#
#   User log in as staff or customer, choose to log in, enter username and password and the system match the input data with the input file's username and password.
#
# * **Scenario 2: User sign up as either staff or customer successfully**
#
#   User sign up as staff or customer, choose to sign up, enter username and password and the system updates input file.
#
# * **Scenario 3: User log in as either staff or customer by entering wrong username or password**
#
#   In this scenario, the input data does not match the input file's username and password. The system communicates the unavailability of log in to the user, who then decides to log in or sign up again.
#
# * **Scenario 4: Users can sign up as either staff or customers by entering a username and password that have been previously registered**
#
#   In this scenario, the input data match with the input file's username and password. The system communicates the unavailability of sign up to the user, who then decides to log in or sign up again.

# %% [markdown]
# ### **Second Scenario : Staff Edit Inventory**
#
# Our team begins by identifying a fundamental use case: "Staff Edit Inventory". This use case encapsulates the primary interaction between user and the system, representing the core functionality of the self-service kiosk.
#
# * **Scenario 1: Users edit inventory successfully**
#
#   User edit inventory, choose the item that want to edit, choose to edit its type, flavour, piece, weight or price per weight, edit with the correct datas and the system updates inventory.
#
# * **Scenario 2: Users edit inventory by entering invalid datas (etc. Type)**
#
#   In this scenario, the system communicates the invalidation of input to the user, who then need to edit the item's type again and updates inventory.

# %% [markdown]
# ### **Third Scenario : Staff Add New Item**
#
# Our team begins by identifying a fundamental use case: "Staff Add New Item". This use case encapsulates the primary interaction between user and the system, representing the core functionality of the self-service kiosk.
#
# * **Scenario 1: Users add new item successfully**
#
#   User add new item to the inventory, enter information of new item such as type, flavour, piece, weight per piece and price per weight and the system updates inventory.
#
# * **Scenario 2: Users add new items by entering invalid datas (etc. Type)**
#
#   In this scenario, the system communicates the invalidation of input to the user, who then need to input the item's type again and updates inventory.

# %% [markdown]
# ### **Fourth Scenario : Customer Places an Order**
#
# The team begins by identifying a fundamental use case: Customer Places an Order.” This use case encapsulates the primary interaction between the user and the system, representing the core functionality of the self-service kiosk.
#
# * **Scenario 1: Successful Order Placement**
#
#   The user adds items by piece or weight to the cart, proceeds to payment, and confirms the order and the system updates inventory.
#
# * **Scenario 2: Order with Promotion**
#
#   Additional interactions with the Discount Service are depicted, showing how the discount code affects the order total.
#
# * **Scenario 3: Order with Out-of-Stock Items**
#
#   In this scenario, the Inventory System communicates the unavailability of an item to the user, who then decides to replace the item.
#
# * **Scenario 4: Choose Wrong Items**
#
#   In this scenario, user remove the item by themselves and updates inventory.
#
# * **Scenario 5: Place an order without immediate payment**
#
#   In this scenario, user chooses not to proceed with payment yet, but the items in the cart remain.
#
# * **Scenario 5: Does not place order but proceed to payment**
#
#   In this scenario, the Inventory System communicates the unavailability of an item to the user, who then decides to add the item into the cart.

# %% [markdown]
# # **Description of the program requirements**

# %% [markdown]
# We need to conduct research and analysis before designing the system to understand the current system, recognize user expectations and requirements, and identify the steps necessary for developing our system.
#
# **Program requirement**
#
# According to the problem scenario, the program requirements of this system are:
#
# 1. User able to log in and sign up as staff or customer.
# 2. User able to view, edit the inventory and add new items as a staff.
# 3. User able to place an order as a customers.
#
# **System Requirement**
#
# Based on the program requirements, system requirements were defined in order to develop kiosk for selling cookies and cakes. We will show the key features and its description.

# %% [markdown]
# **Features and description:**
#
# 1. Main menu selection: Displays a menu with three option: Exit, Staff and Customer.
#
# 2. Exit confirmation: Display a message to prompt the user to confirm their intention to exit the program.
#
# 3. Login/Sign Up Interface: Displays a menu with three options: Login, Sign Up, and Back to Choose Role.
#
# 4. User Login Interface: Display a message to prompt the user to enter their username and password
#
# 5. Staff Login Authentication: Facilitates the authentication process for staff log in to the system.
#
# 6. Failed Login Notification: Display a message to users when their login attempt has failed due to incorrect username or password.
#
# 7. Successful Login Notification: Display a message notifying users when their login attempt is successful.
#
# 8. User Sign-Up Interface: Display a message to prompt the user to input their desired username and password for the new account.
#
# 9. Staff Account Registration: Enables the registration of new staff accounts within the system.
#
# 10. Failed Sign-Up Notification: Display a message notifying users when their attempt to sign up for a new account fails due to the chosen username already being in use.
#
# 11. Successful Sign-Up Notification:  Display a message notifying users when their attempt to sign up for a new account is successful.
#
# 12. Staff Menu: Displays a menu for staff operations, allowing the user to choose Inventory, Edit Inventory and Add New Item.
#
# 13. Staff Food Menu Display: Displays the inventory of pastries available in the store. It provides detailed information about each type, flavour, piece, weight per piece, and price per weight.
#
# 14. Read Item Index: Display a message to prompts the user to enter the index of an item they would like to edit from the inventory.
#
# 15. Inventory Edit Display: Displays a menu of editable attributes and processes the user's choice to update the corresponding attribute.
#
# 16. Edit Info Validation for Pastry Type: To ensures the type is either "Cookie" or "Cake" and provides feedback to the user if the input is invalid.
#
# 17. Edit Info Validation for Numeric Values: To ensures the input is greater than or equal to zero and provides feedback to the user if the input is invalid.
#
# 18. Write Inventory Information to File: Writes the details of all pastry items in the inventory to a file. (friend function is used to get the private members of pastry item to ease the writing process to the file)
#
# 19. Store Inventory Information: Reads inventory information from a file stream and stores it in an array of pastry objects. (friend function is used to get the private members of pastry item to ease the reading process from the file to the private members of pastry item)
#
# 20. Add New Item: Gathers information from the user to create a new pastry item and sets its attributes based on the input. If the item already exists in the inventory, it updates the quantity. Otherwise, it adds the new item to the inventory.
#
# 21. Check if Inventory is Empty: Checks if the inventory is empty by iterating through all items and examining their quantities.
#
# 22. Set Pastry Values: Sets the attributes of a Pastry object with the provided values.
#
# 23. Add Pastry to Inventory: Add a new Pastry object to the inventory list, ensuring there are no duplicates.
#
# 24. Add Status Display: Displays a message indicating whether an item was successfully added to the inventory or not based on the provided status.
#
# 25. Customer Menu Display: Displays the main menu options for the customers of the "Eid Cookies and Cakes Hub". Customers can choose from options such as viewing the menu, managing their cart, or checking promotions.
#
# 26. Customer Food Menu Display: Displays the food menu options available to customers, allowing them to select items to add to their cart. It provides information about each item, including flavour, type, price per kilogram, and price per piece. Additionally, it notifies customers if an item is out of stock.
#
# 27. Customer Food Buy Method: Display a message to prompt the customer to choose their preferred purchase method by piece (pc) or by weight (kg).
#
# 28. Display Cart and Operations: Displays the contents of the customer's cart, allowing them to view the items they have added for purchase. It provides options to remove items from the cart, proceed to payment, or return to the customer menu.
#
# 29. Add to Cart: adds a new item to the customer's cart. If the item already exists in the cart, it updates the quantity. Otherwise, it adds the new item to the cart. (Overload operator -= to reduce the amount of pastry in the inventory, this can reduce the piece and weight at the same time by using one operator only)
#
# 30. Delete from Cart: Removes a item from the customer's cart based on the user's input. It adjusts the cart's contents by deleting the selected item and updating the cart's size accordingly. (Overload operator += to add the amount of pastry in the inventory, this can increase the piece and weight at the same time by using one operator only)
#
# 31. Calculate Total Price with Discount: Calculates the total price of the items in the customer's cart, considering any applicable discounts.
#
# 32. Customer Payment Process: Display a message to handle the payment process for a customer.
#
# 33. Payment Success Message: Displays a success message to the customer after they have completed a payment transaction.
#
# 34. Update Customer Purchase Record: Updates the purchase record of a customer after they have completed a successful payment transaction.

# %% [markdown]
# **Requirement Validation**
#
# After the analyze the current system and also program requirement, the system requirements were defined and each of this feature get visualize with a wireframe view and tabulated in above. All the requirements were then validated by user. Detailed system design will only start when the users verified that all their requirements on self-service kiosk.

# %% [markdown]
# # **The problem your program is trying to solve using object-oriented programming**

# %% [markdown]
# **My Eid Cookies and Cakes Hub has a self-service kiosk which allows customers to make purchases and staff to check and edit stock.**
#
# 1. Each shop has an inventory for keeping pastry, inventory will also read
# and write data saved previously to be displayed or operated by user.
#
# 2. Detailed information of pastry like type, flavour, weight per piece, price per piece, price and float are recorded.
#
# 3. Each pastry that is currently sold in shop will be stored in the inventory and inventory will calculate the total number of items on sale.
#
# 4. Shop involves UI to display the menu for selling cakes and cookies. For every operation menu that provide choices for staff or customer will be displayed with the aid of UI.
#
# 5. Shop has user which can be classified into 2 groups which are customer and staff
#
# 6. Users have their username and password to log in to their personal account. There are no 2 accounts with same username and password.
#
# 7. If this is their first time using the program users are allowed to register by entering the username and password they would like to have.
#
# 8. Username and password of customer and staff will be stored in different files. Respectively, customer.txt and staff.txt .
#
# 9. Customer can browse for pastry selling in the shop by reading the menu displayed by UI
# When displaying menu, information of pastry will be read from inventory.
#
# 10. Once customer is interested with any pastry they could add it into their personal shopping cart. When the pastry is added into cart, inventory will update automatically to decrease amount of stock left.
#
# 11. Customer can check their cart and remove the pastry that they don't really like from it. When pastry is removed from cart inventory will automatically update and increase the amount of pastry.
#
# 12. If customer is satisfied can proceed to payment. Once payment is completed the cart will be emptied and the purchase amount will be recorded.
#
# 13. Staff is allowed to add new pastry into inventory, UI will provide guidance for staff to enter the information required. Once data is received correctly inventory will write the data into inventory.txt for saving purposes.
#
# 14. Edit information of pastry can be done by staff as well. Staff could access the data in inventory and overwrite the information of pastry like type, flavour, price and etc. The changes will be update by inventory in inventory.txt too.

# %% [markdown]
# # **Problem Analysis**

# %% [markdown]
# Tradisional methods of purchasing Eid cookies and cakes might not good for everyone especially for introverted or socially anxious individuals and people with speech impediments where customers need to purchase by expressign their needs to staffs. In addition, the number of people working in bakeries has decreased. The self-service kiosk for selling Eid cookies and cakes aims to ease people by providing a user-friendly purchasing experience while effectively showcasing our cookies and cakes.

# %% [markdown]
# ## **Input**

# %% [markdown]
# 1. **Menus of choosing as a staff or customer**
#
#   We have provided a menu to allow users specify their role within the system, either as a staff or customer to ensure appropriate access.
#
#   Users can interact with the system through menu and make selections. If users want to exit the program can choose to exit as well.
#
# 2. **Login or sign up scene**
#
#   We have allowed users to log in or sign up as either staff or customer.
#
#   Users can either log in with existing username and password or sign up for a new account, depending on whether they are staffs or customers. If users want back to choose role menu, can return back to the menu.
#
# 3. **Staff Functions**
#
#   We have provide a staff with the ability to manage inventory, check the current stock levels, editing existing items with its details (type, flavor, pieces, weight, price per weight), and adding new stock items with its details(type, flavour, how many pieces available, weight per piece, price per weight).
#
#   Staff can check the inventory, edit inventory by editing type, flavour, piece, weight, price per weight. Staffs can add new stocks by entering type, flavour, pieces, weight per piece and price per weight.
#
# 4. **Customer Functions**
#
#   We have enable customers to choose available cookies and cakes, add items to their cart, check the promotion of the day and exit the program.
#
#   Customers can view the menu of cookies and cakes, select items to add to their cart, specify the quantity (either by piece or weight), check the promotion of the day and exit the program.
#
# 5. **Cart Management for Customers**
#
#   We have allowed customers to remove items from their cart, proceed with payment and return to customer menu.
#
#   Customers can manage their cart by removing items, proceeding with payment when ready and returning to their customer menu.
#
# 6. **Payment Pages**
#
#   We have allowed customers to pay their items so that they can get what they desired.
#
#   Customers can choose to pay or not at the end.

# %% [markdown]
# ## **Process**

# %% [markdown]
# 1. **Menus of choosing as a staff or customer**
#
#   The program will use the user's input to direct them to the corresponding user interface and functionalities that tailored to their role. When users exit, our program will confirm with user again for exiting the program.
#
# 2. **Login or sign up scene**
#
#   The program will authenticate user's username and password. When log in, the program will match the username and password you sign up before and grant access to your account. If the username and password not match what we have on record, you may need to log in again with correct username and password or you need to sign up. If users sign up using a username that has already been registered, they will need to log in instead. For new users, the program will facilitate the sign up process and store their information securely.
#   Once logged in or signed up, you'll have access to all the features and functionalities tailored to your role as either staff or a customer.
#
# 3.   **Staff Functions**
#
#   The program allow staff to access inventory management, providing interfaces for checking current stock levels, editing item details (type, flavor, pieces, weight, price per weight), and adding new stock items with its details(type, flavour, how many pieces available, weight per piece, price per weight). It will also validate inputs to prevent duplicate entries and wrong datas.
#
# 4. **Customer Functions**
#
#   The program will provide interfaces for customers to check the menu, select items and manage their cart. It will validate item availability whether it is out of stock or in stock and the quantity inputs. The users can exit the program if they want.
#
# 5. **Cart Management for Customers**
#
#   The program will provide customers with interfaces for managing their cart, including removing items, proceeding to payment and returning to customer menu.
#
# 6. **Payment Pages**
#
#   The program will reduce the items that was bought by customer if customer have paid the items.

# %% [markdown]
# ## **Output**

# %% [markdown]
# 1. **Menus of choosing as a staff or customer**
#
#   Display a menu for the user to choose their role staff or customer or end the program.
#
# 2. **Login or sign up scene**
#
#   After choosing their role, display a menu for choosing whether to log in or sign up. Appropriate messages will be displayed based on the condition. Such as incorrect username and password, username has been used, successfully registered or login.
#
# 3. **Output File for Staff**
#
#   staff.txt is a file that is used to save staff's username and password when staff register to our program. This is a file where staff try to log in will match the username and password that stored in staff.txt.
#
# 4. **Output File for Customer**
#
#   customer.txt is used for recording the username and password of the customers when signed up. This is a file where customer try to log in will match the username and password that stored in customer.txt. Their purchase record will be recorded as well.
#
# 3.  **Staff Functions**
#
#   After the user chooses their role as staff and goes through the login or sign-up process staff menu is displayed. Provide options like exit, check inventory, edit information of existing items in inventory and also add new item into inventory.
#
#   For edit inventory, staff user is allowed to choose index of items that they would like to amend their information. Next, a menu of information that allows editing will be displayed and the user could enter their choice.
#
#   While adding a new item to the inventory, a menu is displayed and requests the user to provide all required information of item. At the end, program will display a message about whether the item was added to the inventory successfully or not.
#
# 4. **Customer Functions**
#
#   The customer menu provides options like displaying the pastry menu, checking shopping cart and checking promotion of the day.
#
#   When customers choose to display menu, the menu of pastries on sale will be shown. Customers may choose the index of item they would like to purchase and proceed to purchase method which customer could buy by piece or weight.
#
#   Detailed information of discounts or promotions will be displayed to encourage customers to purchase more items at a valuable price.
#
#
# 5. **Cart Management for Customers**
#
#   For the option to check the shopping cart, customers are provided with the operation option to remove item, proceed to payment and return to the customer menu. Customers could choose index of item in their cart that they would like to remove to complete the process.
#
# 6. **Payment Pages**
#
#   While proceeding to payment, program will display a confirmation message to the customer. If payment succeeds a message will be displayed to notify the user about that.

# %% [markdown]
# ## **Constraint**

# %% [markdown]
# 1. **Consistent input and output file format**
#
#   The input files format such as customer.txt allow to contain username, password and the number of purchase made by customers.
#
#   The output files format such as staff.txt allow to contain username and password.
#
# 2. **Other constraint**
#
#   Usage of global variable is restricted unless it is a constant variable.
#
#   Not allow to use vector, list, queue, or any possible data structure provided by the built-in C++ library.
#
#   Usage of public member variable is restricted.
#
#   Avoid using friend classes.

# %% [markdown]
# ##**Assumption**

# %% [markdown]
# 1. **User input validation**
#
#   The program assume users input valid and correct datas within the range, it will lead the program to display error messages if users enter index out of the range. The program will again prompt the user for new input.
#
#   The program allows users to buy pieces and weight of cookies and cakes available.
#
#   The program allow users choose items available only and will display error messages if users choose items out of the stock.
#
# 2. **User Authentication**
#
#   The program assumes users will enter valid credentials for authentication.
#
#   The program will check the user's credentials with the respective txt file depending on user's role. staff.txt is used to check staff's username and password while customer.txt is used to check customer's username and password.
#
#   Wrong username and password will prompt user to choose to login again or sign up.

# %% [markdown]
# # **How to run the program**

# %% [markdown]
# ##.txt file

# %%
# %%writefile staff.txt
# Username Password
# myStaff 123123
# Out:
# Overwriting staff.txt

# %%
# %%writefile customer.txt
# Username Password purchaseCount
# myCus 321321 1
# Out:
# Overwriting customer.txt

# %%
# %%writefile inventory.txt
# Type Flavour Piece Weight WeightPerPiece PricePerWeight
# Cake Lemon 10.5 0.0 0.1 100.0
# Cake Mango 12 2 0.167 90.0
# Cookie Chocolate 10 0.3 0.03 35.0
# Cookie Original 10 0.3 0.03 30.0
# Out:
# Overwriting inventory.txt

# %% [markdown]
# ##Main code

# %% [markdown]
# ###Header file

# %%
# %%writefile Shop.h
# #ifndef SHOP_H
# #define SHOP_H
# #include "User.h"
# #include "View.h"
# #include "Inventory.h"
# #include "Pastry.h"
#
# class Shop {
#     private:
#         User* user;
#         View UI;
#         Inventory inventory;
#     public:
#         // Shop constructor
#         Shop();
#         // Shop destructor
#         ~Shop();
#         // Start
#         void main();
#         // Staff Login/Signup
#         int staffLogSign();
#         // Customer Login/Signup
#         int customerLogSign();
#         // Staff Menu
#         int staffMenu();
#         // Customer Menu
#         int customerMenu();
#         // Customer Payment Menu
#         int customerPayment();
# };
#
# #endif
# Out:
# Overwriting Shop.h

# %%
# %%writefile User.h
# #ifndef USER_H
# #define USER_H
# #include "Cart.h"
# #include <string>
# using namespace std;
#
# class User {
#     protected:
#         string username;
#         string password;
#     public:
#         // Constructor
#         User();
#
#         // Get function
#         string getUsername() { return username; };
#
#         // Login logic
#         virtual bool login(string, string) = 0;
#         virtual bool signUP(string, string) = 0;
# };
#
# // Inherited base class User
# class Staff : public User {
#     public:
#         // Constructor
#         Staff();
#
#         // Log In logic
#         bool login(string, string) override;
#         bool signUP(string, string) override;
# };
#
#
# // Inherited base class User
# class Customer : public User {
#     private:
#         int purchaseCount;
#         Cart shopcart;
#     public:
#         // Constructor
#         Customer();
#
#         // Log In logic
#         bool login(string, string) override;
#         bool signUP(string, string) override;
#
#         // Get function
#         Cart& getCart() { return shopcart; };
#         int getPurchaseCount() { return purchaseCount; };
#
#         // Write purchase record of customer in text file
#         void addPurchaseRecord();
# };
#
# #endif
# Out:
# Overwriting User.h

# %%
# %%writefile View.h
# #ifndef VIEW_H
# #define VIEW_H
# #include "Inventory.h"
# #include "Pastry.h"
# #include "Cart.h"
# #include <string>
# using namespace std;
#
# class View {
#     public:
#
#         //User input validation
#         bool validateInput(int, int, int);
#         bool validatePieceAndWeight(float, float);
#         bool validateOutofStock(int, const Inventory&);
#         bool editInfoValidation(string);
#         bool editInfoValidation(float);
#
#         // User sign in
#         int mainmenu();
#         int logSignUI();
#         void loginUI(string&, string&);
#         void signUpUI(string&, string&);
#         void failLogin();
#         void failSignUP();
#         void successLogin(string);
#         void successSignUP(string);
#
#         // Staff menu
#         int staffMenuDisplay();
#         void staffFoodMenuDisplay(const Inventory&);
#         int inventoryEditDisplay(Inventory&, int);
#         int readItemIdx(const Inventory&);
#         void addNewItem(Pastry&, const Inventory&);
#         void addStatusDisplay(bool);
#
#         // Customer menu
#         int customerMenuDisplay();
#         int customerFoodMenuDisplay(const Inventory&);
#         int customerFoodBuyMethod();
#         float customerBuyByPiece(Pastry&);
#         float customerBuyByWeight(Pastry&);
#         int displayCart(const Cart&);
#         int deleteCartItem(const Cart&);
#         void checkPromo();
#         int payment(const Cart&, int);
#         void successPaid(string);
#
#         // Confirm to exit
#         bool exitConfirmation();
#
# };
#
# #endif
# Out:
# Overwriting View.h

# %%
# %%writefile Inventory.h
# #ifndef INVENTORY_H
# #define INVENTORY_H
# #include "Pastry.h"
#
# class Inventory {
#     private:
#         Pastry* pastryList;
#         int totalItemNo;
#     public:
#         // Constructor
#         Inventory();
#
#         // Destructor
#         ~Inventory();
#
#         // Get function
#         Pastry* getPastryList() const;
#         int getItemNumber() const;
#
#         // Read all the stock in the inventory.txt
#         // and update it to the pastrylist of Inventory
#         void read();
#
#         // Wrire info in pastrylist into inventory.txt
#         void write();
#
#         // Check is pastrylist empty
#         bool checkAllEmpty() const;
#
#         // Update inventory when item is removed from customer cart
#         void addLocalInventory(Pastry);
#
#         // Update pastrylist when new item is added
#         bool addPastryList(Pastry&);
#
# };
#
# #endif
# Out:
# Overwriting Inventory.h

# %%
# %%writefile Cart.h
# #ifndef CART_H
# #define CART_H
# #include "Pastry.h"
# #include "Inventory.h"
#
# class Cart {
#     private:
#         Pastry* inCartItem;
#         int amount;
#     public:
#         // Constrcutor
#         Cart();
#
#         // Destructor
#         ~Cart();
#
#         // Get function
#         int getAmount() const { return amount; };
#         Pastry* getInCartItem() const;
#         float getTotalPrice(int, bool&) const;
#
#         // Add pastry into cart
#         void addToCart(Pastry);
#
#         // Delete pastry into cart
#         void deleteFromCart(int);
#
# };
#
# #endif
# Out:
# Overwriting Cart.h

# %%
# %%writefile Pastry.h
# #ifndef PASTRY_H
# #define PASTRY_H
# #include <string>
# #include <fstream>
# using namespace std;
#
# class Pastry {
#     private:
#         string type;
#         string flavour;
#         float weightperpiece;
#         float priceperweight;
#         float piece;
#         float weight;
#     public:
#         // Default constructor
#         Pastry();
#
#         // Destructor
#         ~Pastry();
#
#         // Friend function for read and write info from text file
#         friend void storeInfo(fstream&, Pastry*, int);
#         friend void writeInfo(fstream&, Pastry*, int);
#
#         // Get function
#         string getType() { return type; };
#         string getFlavour() { return flavour; };
#         float getWPP() { return weightperpiece; };
#         float getPPP() { return (priceperweight * weightperpiece); };
#         float getPPW() { return priceperweight; };
#         float getPiece() { return piece; };
#         float getWeight() { return weight; };
#         float getPrice() { return(priceperweight * weight); };
#
#         // Set function
#         void setType(string);
#         void setFlavour(string);
#         void setWPP(float);
#         void setPPW(float);
#         void setPiece(float);
#         void setWeight(float);
#         void setPastryValue(string, string, float, float, float, float);
#
#         // Overload - operator
#         Pastry& operator-=(const Pastry&);
#         // Overload + operator
#         Pastry& operator+=(const Pastry&);
#         // Overload = operator
#         bool operator==(const Pastry&);
#
# };
#
# #endif
# Out:
# Overwriting Pastry.h

# %% [markdown]
# ###Implementation file

# %%
# %%writefile Shop.cpp
# #include "Shop.h"
# #include <iostream>
# using namespace std;
#
# //Shop constructor
# Shop::Shop() {
#     user = nullptr;
# }
#
# //Shop destructor
# Shop :: ~Shop() {
#     delete user;
# }
#
# void Shop::main() {
#     delete user;
#     user = nullptr;
#     while (true) {
#         int choice, returnChoice;
#         choice = UI.mainmenu();
#         switch (choice) {
#             case 0:
#                 // Call exitConfirmation() in View class to display Y/y to exit program and return true to exit the program
#                 if (UI.exitConfirmation()) {
#                     cout << "\nThanks for your visiting!" << endl;
#                     cout << endl;
#                     return;
#                 }
#                 // if false (meaning not Y/y input), loop continues
#                 break;
#
#             case 1:
#                 // Call staff menu to display login/sign up for staff
#                 returnChoice = staffLogSign();
#                 //Display program ended message
#                 if (returnChoice == 0) {
#                     cout << "\nProgram Ended. Keep up the excellent work!" << endl;
#                     cout << endl;
#                     return;
#                 }
#                 break;
#             case 2:
#                 // Call customer menu to display login/sign up for customer
#                 returnChoice = customerLogSign();
#                 //Display program ended message
#                 if (returnChoice == 0) {
#                     cout << "\nThank you for visiting our shop! We hope to see you again soon." << endl;
#                     cout << endl;
#                     return;
#                 }
#                 break;
#             default:
#                 break;
#         }
#     }
# }
#
# int Shop::staffLogSign() {
#     // user hold Staff() address
#     user = new Staff();
#     int choice, returnChoice;
#     // Assign false because haven't login or sign up yet
#     bool isLogin = false;
#     bool isSignUp = false;
#     while (!isLogin) { // program loop if isLogin false
#         choice = UI.logSignUI(); // Call logSignUI() in View class
#         string username, password;
#         switch (choice) {
#         case 1:
#             //Staff login
#             UI.loginUI(username, password);
#             isLogin = user->login(username, password); // Call login() to check if username and password is correct
#             if (!isLogin) {
#                 //Call failLogin() in View class to display failed login
#                 UI.failLogin();
#             }
#             else {
#                 //Call successLogin() in View class to display successfully login
#                 UI.successLogin(username);
#                 returnChoice = staffMenu();
#                 return returnChoice;
#             }
#             break;
#         case 2:
#             //Staff sign up
#             UI.signUpUI(username, password);
#             isSignUp = user->signUP(username, password);
#             if (!isSignUp) {
#                 UI.failSignUP();
#             }
#             else {
#                 isLogin = true;
#                 UI.successSignUP(username);
#                 returnChoice = staffMenu();
#                 return returnChoice;
#             }
#             break;
#         case 3:
#             //Return to role selection menu
#             return 3;
#         }
#     }
#     return 0;
# }
#
# int Shop::customerLogSign() {
#     user = new Customer();
#     int choice, returnChoice;
#     bool isLogin = false;
#     bool isSignUp = false;
#     while (!isLogin) {
#         choice = UI.logSignUI();
#         string username, password;
#         switch (choice) {
#         case 1:
#             //Customer login
#             UI.loginUI(username, password);
#             isLogin = user->login(username, password);
#             if (!isLogin) {
#                 UI.failLogin();
#             }
#             else {
#                 UI.successLogin(username);
#                 returnChoice = customerMenu();
#                 return returnChoice;
#             }
#             break;
#         case 2:
#             //Customer sign up
#             UI.signUpUI(username, password);
#             isSignUp = user->signUP(username, password);
#             if (!isSignUp) {
#                 UI.failSignUP();
#             }
#             else {
#                 isLogin = true;
#                 UI.successSignUP(username);
#                 returnChoice = customerMenu();
#                 return returnChoice;
#             }
#             break;
#         case 3:
#             //Return to role selection menu
#             return 3;
#         }
#     }
#     return 0;
# }
#
# int Shop::staffMenu() {
#     Pastry newPastry;
#     int choice, idxItem, editChoice;
#     bool confirm=false, status;
#     while (true) {
#         // Call staffMenuDisplay() in View class to display staff operations menu
#         choice = UI.staffMenuDisplay();
#         switch (choice) {
#             case 0:
#                 //Exit program
#                 if (UI.exitConfirmation())
#                     return 0;
#                 break;
#
#             case 1:
#                 //Call staffFoodMenuDisplay in View Class to display Inventory
#                 UI.staffFoodMenuDisplay(inventory);
#                 break;
#
#             case 2:
#                 // Edit inventory
#                 UI.staffFoodMenuDisplay(inventory);
#                 idxItem = UI.readItemIdx(inventory);
#                 editChoice = UI.inventoryEditDisplay(inventory, idxItem);
#                 // Update inventory.txt
#                 inventory.write();
#                 if (editChoice == 0) {
#                     if(UI.exitConfirmation())
#                         return 0;
#                 }
#                 break;
#
#             case 3:
#                 //Add new item into inventory
#                 UI.addNewItem(newPastry, inventory);
#                 status=inventory.addPastryList(newPastry);
#                 UI.addStatusDisplay(status);
#                 // Update inventory.txt
#                 inventory.write();
#                 break;
#
#             default:
#                 break;
#         }
#     }
#     return 0;
# }
#
# int Shop::customerMenu() {
#     Pastry selectedPastry, deletePastry;
#     int choice, selectItem, buyMethod, viewCartOption, returnChoice;
#     float piece, weight;
#     while (true) {
#         choice = UI.customerMenuDisplay();
#         switch (choice) {
#             case 0:
#                 //Exit program
#                 if (UI.exitConfirmation()) {
#                     return 0;
#                 }
#                 break;
#             case 1:
#                 //Display pastry menu
#                 selectItem = UI.customerFoodMenuDisplay(inventory);
#                 if (selectItem <= 0) {
#                     break;
#                 }
#                 buyMethod = UI.customerFoodBuyMethod();
#                 selectedPastry = inventory.getPastryList()[selectItem - 1];
#                 if (buyMethod == 1) {
#                     piece = UI.customerBuyByPiece(selectedPastry);
#                     selectedPastry.setPiece(piece);
#                 }
#                 else if (buyMethod == 2) {
#                     weight = UI.customerBuyByWeight(selectedPastry);
#                     selectedPastry.setWeight(weight);
#                 }
#                 // Reduce inventory
#                 inventory.getPastryList()[selectItem - 1] -= selectedPastry;
#                 // Add to Cart
#                 static_cast<Customer*>(user)->getCart().addToCart(selectedPastry);
#                 break;
#             case 2:
#                 //Cart operation
#                 while (true) {
#                     viewCartOption = UI.displayCart(static_cast<Customer*>(user)->getCart());
#                     if (viewCartOption == 1) { // Delete item
#
#                         if ((static_cast<Customer*>(user)->getCart().getAmount()) == 0) {
#                             cout << "The cart is empty! Nothing can be removed.";
#                             cout << endl;
#                             break;
#                         }
#
#                         int deleteItemNo = UI.deleteCartItem(static_cast<Customer*>(user)->getCart());
#                         if (deleteItemNo == -1) {
#                             continue;
#                         }
#                         // Add back to inventory before deleting
#                         inventory.addLocalInventory(static_cast<Customer*>(user)->getCart().getInCartItem()[deleteItemNo - 1]);
#                         // Delete from cart
#                         static_cast<Customer*>(user)->getCart().deleteFromCart(deleteItemNo);
#                     }
#                     else if (viewCartOption == 2) { // Payment
#
#                         if ((static_cast<Customer*>(user)->getCart().getAmount()) == 0) {
#                             cout << "The cart is empty! Add something before proceed to payment.";
#                             cout << endl;
#                             break;
#                         }
#                         returnChoice = customerPayment();
#                         if (returnChoice == 2) {
#                             break;
#                         }
#                         return returnChoice;
#                     }
#                     else {
#                         break;
#                     }
#                 }
#                 break;
#             case 3:
#                 //Display details of promotion
#                 UI.checkPromo();
#                 break;
#
#             default:
#                 break;
#         }
#     }
#     return 0;
# }
#
# int Shop::customerPayment() {
#     int choice;
#     choice = UI.payment(static_cast<Customer*>(user)->getCart(), static_cast<Customer*>(user)->getPurchaseCount());
#     switch (choice) {
#     case 1:
#         // Pay process
#         UI.successPaid(user->getUsername());
#         // Update customer purchase record
#         static_cast<Customer*>(user)->addPurchaseRecord();
#         // Inventory update to database
#         inventory.write();
#         break;
#     case 2:
#         // Back to customer menu
#         return 2;
#     }
#     return 0;
# }
# Out:
# Overwriting Shop.cpp

# %%
# %%writefile User.cpp
# #include <iostream>
# #include <fstream>
# #include "User.h"
# using namespace std;
#
# // Constructor initializes username and password as empty strings
# User::User() {
#     username = "";
#     password = "";
# }
#
# Staff::Staff() : User() {}
#
# bool Staff::login(string userN, string pw) {
#     fstream staffFile;
#     staffFile.open("staff.txt", ios::in);
#     string u, p, header;
#     getline(staffFile, header);
#     //Reading data from the input file stream 'staffFile'
#     while (staffFile >> u >> p) {
#         //If the u and p data (stored inside file) same with userN and pw which is user's input, it will stored in username and password which in protected access specifier
#         if (userN == u && pw == p) {
#             username = userN;
#             password = pw;
#             staffFile.close();
#             return true;
#         }
#     }
#     staffFile.close();
#     return false;
# }
#
# // The signUP method checks if the username is unique and adds the new user to the staff.txt file
# bool Staff::signUP(string newUsername, string newPassword) {
#     fstream staffFile;
#     staffFile.open("staff.txt", ios::in);
#     string u, p, header;
#     getline(staffFile, header);
#     // Check if the new username already exists in the staff.txt file
#     while (staffFile >> u >> p) {
#         if (newUsername == u) {
#             return false; // Username already exists, sign-up failed
#         }
#     }
#     staffFile.close();
#     staffFile.open("staff.txt", ios::app);
#     // If the username is unique, write the new user's data to the staff.txt file
#     staffFile << newUsername << " " << newPassword << endl;
#     // Update the username and password for the current Staff object
#     username = newUsername;
#     password = newPassword;
#     staffFile.close();
#     return true; // Sign-up successful
# }
#
# Customer::Customer() : User() {}
#
# // The login method checks if the given username and password match the stored data in the customer.txt file
# bool Customer::login(string userN, string pw) {
#     fstream customerFile;
#     customerFile.open("customer.txt", ios::in);
#     string u, p, header;
#     int c;
#     getline(customerFile, header);
#     // Read data from the customer.txt file
#     while (customerFile >> u >> p >> c) {
#         // If the username and password match the input, update the username, password, and purchaseCount for the current Customer object
#         if (userN == u && pw == p) {
#             username = userN;
#             password = pw;
#             purchaseCount = c;
#             customerFile.close();
#             return true; // Login successful
#         }
#     }
#     customerFile.close();
#     return false; // Login failed
# }
#
# // The signUP method checks if the username is unique and adds the new user to the customer.txt file
# bool Customer::signUP(string newUsername, string newPassword) {
#     fstream customerFile;
#     customerFile.open("customer.txt", ios::in);
#     string u, p, header;
#     int c;
#     getline(customerFile, header);
#     // Check if the new username already exists in the customer.txt file
#     while (customerFile >> u >> p >> c) {
#         if (newUsername == u) {
#             return false; // Username already exists, sign-up failed
#         }
#     }
#     customerFile.close();
#     customerFile.open("customer.txt", ios::app);
#     // If the username is unique, write the new user's data to the customer.txt file
#     customerFile << newUsername << " " << newPassword << " " << 0 << endl;
#     // Update the username, password, and purchaseCount for the current Customer object
#     username = newUsername;
#     password = newPassword;
#     purchaseCount = 0;
#     customerFile.close();
#     return true; // Sign-up successful
# }
#
# // The addPurchaseRecord method updates the purchase count for the current Customer object and writes the updated data to the customer.txt file
# void Customer::addPurchaseRecord() {
#     // customer made a purchase so purchaseCount +1
#     purchaseCount++;
#     // Update the purchaseCount to txt file
#     fstream customerFile("customer.txt", ios::in | ios::out);
#     streampos position = 0;
#     string linetochange = username + " " + password + " " + to_string(purchaseCount - 1);
#     string newline = username + " " + password + " " + to_string(purchaseCount);
#     string line;
#     // Skip the header of the file
#     getline(customerFile, line);
#     // Search for the line in the customer.txt file that matches the linetochange string
#     while (true) {
#         position = customerFile.tellg();
#         while (getline(customerFile, line)) {
#             if (line == linetochange) {
#                 // If the line is found, update the position and write the newline string to the customer.txt file
#                 customerFile.seekp(position);
#                 customerFile << newline;
#                 customerFile.close();
#                 return;
#             }
#             else {
#                 break;
#             }
#         }
#     }
# }
# Out:
# Overwriting User.cpp

# %%
# %%writefile View.cpp
# #include "View.h"
# #include <iostream>
# #include <fstream>
# #include <iomanip>
# #include <string>
#
# using namespace std;
#
# const int MAX_STREAM_SIZE = 32767;
#
# // A helper function to validate the input
# bool View::validateInput(int userInput, int min, int max) {
#     // if cin.fail() to check if the input is invalid, different data type input
#     // !cin.fail() to check if the input is valid
#     if (!(cin.fail()) && userInput >= min && userInput <= max) {
#         return false;
#     }
#     else {
#         cout << endl;
#         cout << "ERROR: Input must be from " << min << " to " << max << "." << endl;
#         cout << endl;
#         // since the input might be char for int type, so we need to clear the error flag
#         cin.clear();
#         // and clear any input buffer
#         cin.ignore(MAX_STREAM_SIZE, '\n');
#         return true;
#     }
# }
#
# void View::checkPromo() {
#     // To show the promo message
#     cout << endl;
#     cout << "-----------------------------------------------------" << "\n"
#          << "|                Promotion Of The Day                |" << "\n"
#          << "-----------------------------------------------------" << "\n"
#          << "|                First time purchase                 |" << "\n"
#          << "|                                                    |" << "\n"
#          << "|                        AND                         |" << "\n"
#          << "|                                                    |" << "\n"
#          << "|             For every 5 purchases made             |" << "\n"
#          << "|                                                    |" << "\n"
#          << "|            YOU WILL GET A 10% DISCOUNT!            |" << "\n"
#          << "-----------------------------------------------------" << "\n";
# }
#
#
# int View::payment(const Cart& cart, int userPurchaseCount) {
#     int choice;
#     cout << endl;
#     cout << "----------------------------------------------------" << "\n"
#         << "|                      Checkout                      |" << "\n"
#         << "-----------------------------------------------------" << "\n"
#         << "|      Item            Price           Amount        |" << "\n"
#         << "-----------------------------------------------------" << "\n";
#     // call Cart getter function to get all information needed
#     for (int i = 0; i < cart.getAmount(); i++) {
#         cout << "|                                                    |" << "\n";
#         string itemName = cart.getInCartItem()[i].getFlavour() + " " + cart.getInCartItem()[i].getType();
#         // Check if item name too long put ... at the back to prevent display error
#         if (itemName.length() >= 20) {
#             itemName = itemName.substr(0, 20) + "...";
#         }
#         cout << "|  ";
#         cout << setw(20) << left << itemName << "RM"
#             << setw(10) << fixed << setprecision(2) << showpoint << cart.getInCartItem()[i].getPrice()
#             << setw(19) << right << to_string(static_cast<int>(cart.getInCartItem()[i].getPiece())) + "          |" << endl;
#         cout << "|                                                    |" << "\n";
#     }
#     float total;
#     bool gotDiscount = false;
#     // call payment function to calculate the total price and discount
#     total = cart.getTotalPrice(userPurchaseCount, gotDiscount);
#     // Different cases of output if got discount or not
#     if (!gotDiscount) {
#         cout << "-----------------------------------------------------" << "\n"
#             << "     Total: " << setw(13) << fixed << setprecision(2) << showpoint << right << "RM" << total << "\n"
#             << "-----------------------------------------------------" << "\n";
#     }
#     else {
#         cout << "-----------------------------------------------------" << "\n"
#             << "     Total: " << setw(13) << fixed << setprecision(2) << showpoint << right << "RM" << total / 0.9 << "\n"
#             << "- Discount: " << setw(13) << fixed << setprecision(2) << showpoint << right << "RM" << total / 0.9 * 0.1 << "\n"
#             << "=    Final: " << setw(13) << fixed << setprecision(2) << showpoint << right << "RM" << total << "\n"
#             << "-----------------------------------------------------" << "\n";
#     }
#     do {
#         cout << "Pay?" << endl;
#         cout << "1. Yes" << endl;
#         cout << "2. No" << endl;
#         cout << "Your choice: ";
#         cin >> choice;
#     } while (validateInput(choice, 1, 2));
#     return choice;
# }
#
# bool View::validatePieceAndWeight(float userInput, float max) {
#     if (!(cin.fail()) && userInput > 0.0 && userInput <= max) {
#         return false;
#     }
#     else {
#         // Show max value of item they can add.
#         cout << endl;
#         cout << "Oops! Unable to add into cart. Limited stocks available: " << max << "." << endl;
#         cout << endl;
#         cin.clear();
#         cin.ignore(MAX_STREAM_SIZE, '\n');
#         return true;
#     }
# }
#
# // Another helper function to validate the out of stock
# bool View::validateOutofStock(int userInput, const Inventory& inventory) {
#     Pastry* pastryList = inventory.getPastryList();
#     // If user still choice the items out of stock, it will display item sold out
#     if (pastryList[userInput - 1].getPiece() <= 0) {
#         cout << endl;
#         cout << "Item sold out! Please select other variation." << endl;
#         return true;
#     }
#     return false;
# }
#
# //Display menu for selling Eid cookies and cakes
# int View::mainmenu() {
#     int choice = -1;
#     do {
#         cout << endl;
#         cout << "-----------------------------------------------------" << "\n"
#             << "|      Welcome to My Eid Cookies and Cakes Hub       |" << "\n"
#             << "-----------------------------------------------------" << "\n"
#             << "| Please enter (0-2):                                |" << "\n"
#             << "| 0. Exit                                            |" << "\n"
#             << "| 1. Staff                                           |" << "\n"
#             << "| 2. Customer                                        |" << "\n"
#             << "-----------------------------------------------------" << endl;
#         cout << "Your choice: ";
#         cin >> choice;
#     } while (validateInput(choice, 0, 2)); // Call validateInput() to ensure user's input is within the range (0-2) in this case
#     // if input is not valid, return true and the loop continues
#     return choice;
# }
#
# int View::logSignUI() {
#     int choice;
#     do {
#         cout << endl;
#         cout << "-----------------------------------------------------" << "\n"
#             << "|                   Login / SignUp                   |" << "\n"
#             << "-----------------------------------------------------" << "\n"
#             << "| Please enter (1-3):                                |" << "\n"
#             << "| 1. Login                                           |" << "\n"
#             << "| 2. Signup                                          |" << "\n"
#             << "| 3. Back to Choose Role                             |" << "\n"
#             << "-----------------------------------------------------" << endl;
#         cout << "Your choice: ";
#         cin >> choice;
#     } while (validateInput(choice, 1, 3));
#     return choice;
# }
#
# int View::staffMenuDisplay() {
#     int choice = -1;
#     do {
#         cout << endl;
#         cout << "-----------------------------------------------------" << "\n"
#             << "|               Staff Operations Menu                |" << "\n"
#             << "-----------------------------------------------------" << "\n"
#             << "| 0. Exit                                            |" << "\n"
#             << "| 1. Inventory                                       |" << "\n"
#             << "| 2. Edit Inventory                                  |" << "\n"
#             << "| 3. Add New Item                                    |" << "\n"
#             << "-----------------------------------------------------" << endl;
#         cout << "Your choice: ";
#         cin >> choice;
#     } while (validateInput(choice, 0, 3));
#     return choice;
# }
#
# int View::customerMenuDisplay() {
#     int choice = -1;
#     do {
#         cout << endl;
#         cout << "-----------------------------------------------------" << "\n"
#             << "|             Eid Cookies and Cakes Hub              |" << "\n"
#             << "-----------------------------------------------------" << "\n"
#             << "| 0. Exit                                            |" << "\n"
#             << "| 1. Menu                                            |" << "\n"
#             << "| 2. Cart                                            |" << "\n"
#             << "| 3. Promotion                                       |" << "\n"
#             << "-----------------------------------------------------" << endl;
#
#         cout << "Your choice: ";
#         cin >> choice;
#     } while (validateInput(choice, 0, 3));
#     return choice;
# }
#
# void View::loginUI(string& username, string& password) {
#     cout << endl;
#     cout << "-----------------------------------------------------" << "\n"
#         << "|                       Login                        |" << "\n"
#         << "-----------------------------------------------------" << "\n"
#         << " Enter your username: ";
#     cin >> username;
#     cout << " Enter your password: ";
#     cin >> password;
#     cout << "-----------------------------------------------------" << endl;
#
# }
#
# void View::signUpUI(string& username, string& password) {
#     cout << endl;
#     cout << "-----------------------------------------------------" << "\n"
#         << "|                       Sign Up                      |" << "\n"
#         << "-----------------------------------------------------" << "\n"
#         << " Enter your username: ";
#     cin >> username;
#     cout << " Enter new password: ";
#     cin >> password;
#
# }
#
# void View::failLogin() {
#     cout << endl;
#     cout << "Your username or password is incorrect. Please try again." << "\n"
#         << "-----------------------------------------------------" << endl;
# }
#
# void View::failSignUP() {
#     cout << endl;
#     cout << "Your username has been used. Please try again." << "\n"
#         << "-----------------------------------------------------" << endl;
# }
#
# void View::successLogin(string username) {
#     cout << endl;
#     cout << "Login successfully. Welcome " << username << "\n"
#         << "-----------------------------------------------------" << endl;
# }
#
# void View::successSignUP(string username) {
#     cout << endl;
#     cout << "Sign up successfully. Welcome " << username << "\n"
#         << "-----------------------------------------------------" << endl;
# }
#
# void View::successPaid(string username) {
#     cout << "-----------------------------------------------------" << endl;
#     cout << "Thank you for your payment. Have a nice day " << username << " !\n";
# }
#
# void View::staffFoodMenuDisplay(const Inventory& inventory) {
#     cout << endl;
#     cout << "---------------------------------------------------------" << "\n"
#         << "|                      Inventory                          |" << "\n"
#         << "----------------------------------------------------------" << "\n";
#     if(inventory.checkAllEmpty()){
#         cout << "No item in the inventory." << endl;
#     }
#     Pastry* pastryList = inventory.getPastryList();
#     int totalItemNumber = inventory.getItemNumber();
#     for (int i = 0; i < totalItemNumber; i++) {
#         cout << i + 1 << ". "
#             << pastryList[i].getFlavour()
#             << " " << pastryList[i].getType()
#             << " " << pastryList[i].getPiece() << "pieces"
#             << " " << pastryList[i].getWeight() << "kg"
#             << " RM" << pastryList[i].getPPW() << "/kg RM"
#             << pastryList[i].getPPP() << "/pc";
#         cout << endl;
#     }
#     cout << "---------------------------------------------------------" << endl;
#
# }
#
# int View::readItemIdx(const Inventory& inventory) {
#     int idx = -1; // index = -1 to check if inventory is empty
#     if(!(inventory.checkAllEmpty())){
#         do {
#             cout << "Enter index of item you would like to edit: ";
#             cin >> idx;
#
#         } while (validateInput(idx, 1, inventory.getItemNumber()));
#     }
#     return idx;
# }
#
# int View::inventoryEditDisplay(Inventory& inventory, int idx) {
#     int choice;
#     float weightperpiece, priceperweight, piece, weight;
#     string type, flavour;
#     if(idx != -1){
#         do {
#             cout << endl;
#             cout<< "-----------------------------------------------------" << "\n"
#                 << "|                   Operation Menu                   |" << "\n"
#                 << "-----------------------------------------------------" << "\n"
#                 << "| 0. Exit                                            |" << "\n"
#                 << "| 1. Type                                            |" << "\n"
#                 << "| 2. Flavour                                         |" << "\n"
#                 << "| 3. Piece                                           |" << "\n"
#                 << "| 4. Weight                                          |" << "\n"
#                 << "| 5. Price Per Weight                                |" << "\n"
#                 << "-----------------------------------------------------" << endl;
#             cout << "Select operations: ";
#             cin >> choice;
#         } while (validateInput(choice, 0, 5));
#
#         Pastry* pastryList = inventory.getPastryList();
#         switch (choice) {
#         case 0:
#             return 0;
#             break;
#         case 1:
#             do {
#                 cout << "Type: ";
#                 cin >> type;
#             } while (editInfoValidation(type));
#             pastryList[idx - 1].setType(type);
#             break;
#         case 2:
#             cout << "Flavour: ";
#             cin >> flavour;
#             pastryList[idx - 1].setFlavour(flavour);
#             break;
#         case 3:
#             do {
#                 cout << "Piece: ";
#                 cin >> piece;
#             } while (editInfoValidation(piece));
#             pastryList[idx - 1].setPiece(piece);
#             pastryList[idx - 1].setWPP(pastryList[idx - 1].getWeight()/piece);
#             break;
#         case 4:
#             do {
#                 cout << "Weight: ";
#                 cin >> weight;
#             } while (editInfoValidation(weight));
#             pastryList[idx - 1].setWeight(weight);
#             pastryList[idx - 1].setWPP(weight/pastryList[idx - 1].getPiece());
#             break;
#         case 5:
#             do {
#                 cout << "Price Per Weight: ";
#                 cin >> priceperweight;
#             } while (editInfoValidation(priceperweight));
#             pastryList[idx - 1].setPPW(priceperweight);
#             break;
#         }
#     }else{
#         cout << endl << "There's no item in the inventory! You cannot edit anything!" << endl;
#     }
#     return 1;
# }
#
# bool View::editInfoValidation(string type) {
#     if (type != "Cookie" && type != "Cake") {
#         cout << "Invalid input. Enter Cookie or Cake only." << endl;
#         return true;
#     }
#     return false;
# }
#
# bool View::editInfoValidation(float num) {
#     if (num < 0.0) {
#         cout << "Value must be greater or equal to 0" << endl;
#         return true;
#     }
#     return false;
# }
#
# void View::addNewItem(Pastry& newPastry, const Inventory& inventory) {
#     float weightperpiece, priceperweight, piece, weight;
#     string type, flavour;
#     cout << endl;
#     cout << "-----------------------------------------------------" << "\n"
#         << "|              Enter Info of New Item                |" << "\n"
#         << "-----------------------------------------------------" << endl;
#     do {
#         cout << "Type: ";
#         cin >> type;
#     } while (editInfoValidation(type));
#
#     cout << "Flavour: ";
#     cin >> flavour;
#
#     do {
#         cout << "How Many Pieces Available: ";
#         cin >> piece;
#     } while (editInfoValidation(piece));
#
#
#     do {
#         cout << "Weight Per Piece: ";
#         cin >> weightperpiece;
#     } while (editInfoValidation(weightperpiece));
#
#     do {
#         cout << "Price Per Weight: ";
#         cin >> priceperweight;
#     } while (editInfoValidation(priceperweight));
#
#     weight = piece * weightperpiece;
#
#     newPastry.setPastryValue(type, flavour, weightperpiece, priceperweight, piece, weight);
#
# }
#
# // To show status message of item added or not
# void View::addStatusDisplay(bool status) {
#     if (status)
#         cout << "\nItem has been added successsfully.";
#     else
#         cout << "\nItem existed fail to add the item.";
# }
#
# int View::customerFoodMenuDisplay(const Inventory& inventory) {
#     int choice = -1;
#     int totalItemNumber;
#     if (!inventory.checkAllEmpty()) { // Inventory is not empty, then only the user can buy item from our shop
#         do {
#             cout << endl;
#             cout << "---------------------------------------------------------" << "\n"
#                 << "|                          Menu                          |" << "\n"
#                 << "---------------------------------------------------------" << "\n";
#             Pastry* pastryList = inventory.getPastryList();
#             totalItemNumber = inventory.getItemNumber();
#             cout << "0. Return to customer menu\n";
#             for (int i = 0; i < totalItemNumber; i++) {
#                 cout << i + 1 << ". "
#                     << pastryList[i].getFlavour()
#                     << " " << pastryList[i].getType()
#                     << " RM" << pastryList[i].getPPW() << "/kg RM"
#                     << pastryList[i].getPPP() << "/pc";
#                 // When pastryList in inventory class object is run out of cake or cookie will display out of stock
#                 if (pastryList[i].getPiece() <= 0) {
#                     cout << " (Out of Stock!)";
#                 }
#                 cout << "\n";
#             }
#             cout << "---------------------------------------------------------" << endl;
#             cout << "Enter index of item to add into cart: ";
#             cin >> choice;
#             if (choice == 0)
#                 return 0;
#         } while (validateInput(choice, 1, totalItemNumber) || validateOutofStock(choice, inventory)); // Except from checking the input in range,
#                                                                                                       // check if the item is out of stock
#     }
#     else { // else show error message that our shop has nothing in stock already.
#         cout << endl;
#         cout << "ERROR: Our shop currently has no items available." << endl;
#     }
#     return choice;
# }
#
# int View::customerFoodBuyMethod() { // Freedom for the customer to buy by weight or by piece.
#     int choice;
#     do {
#         cout << endl;
#         cout << "-------------------------------------" << "\n"
#             << "|           Purchase Method          |" << "\n"
#             << "-------------------------------------" << "\n"
#             << "|    1. Piece(pc)                    |" << "\n"
#             << "|    2. Weight(kg)                   |" << "\n"
#             << "-------------------------------------" << "\n";
#         cout << "Your choice: ";
#         cin >> choice;
#     } while (validateInput(choice, 1, 2));
#     return choice;
# }
#
# float View::customerBuyByPiece(Pastry& itemSelected) {
#     float piece;
#     do {
#         cout << endl;
#         cout << "How many pieces do you want: ";
#         cin >> piece;
#     } while (validatePieceAndWeight(piece, itemSelected.getPiece()));
#     return piece;
# }
#
# float View::customerBuyByWeight(Pastry& itemSelected) {
#     float weight;
#     do {
#         cout << endl;
#         cout << "How many kg do you want: ";
#         cin >> weight;
#     } while (validatePieceAndWeight(weight, itemSelected.getWeight()));
#     return weight;
# }
#
# int View::displayCart(const Cart& customerCart) {
#     Pastry* cartList = customerCart.getInCartItem();
#     cout << endl;
#     cout << "---------------------------------------------------------" << "\n"
#         << "|                          Cart                          |" << "\n"
#         << "---------------------------------------------------------" << "\n";
#
#     if (customerCart.getAmount() == 0) { // Display empty cart message
#         cout << "The Cart is Empty Nothing to See Here" << endl;
#     }
#
#     for (int i = 0; i < customerCart.getAmount(); i++) {
#         cout << i + 1 << ". "
#             << cartList[i].getFlavour()
#             << " " << cartList[i].getType()
#             << " RM" << cartList[i].getPrice()
#             << endl;
#     }
#     cout << "---------------------------------------------------------" << "\n";
#     int choice;
#     do {
#         cout << endl;
#         cout << "-------------------------------------" << "\n"
#             << "|           Operation Menu           |" << "\n"
#             << "-------------------------------------" << "\n"
#             << "|    1. Remove item                  |" << "\n"
#             << "|    2. Proceed to payment           |" << "\n"
#             << "|    3. Return to Customer Menu      |" << "\n"
#             << "-------------------------------------" << "\n"
#             << "Select operation: ";
#         cin >> choice;
#     } while (validateInput(choice, 1, 3));
#     return choice;
# }
#
# int View::deleteCartItem(const Cart& customerCart) {
#     int choice = -1;
#     if (customerCart.getAmount() != 0) {
#         do {
#             cout << endl;
#             cout << "Which item do you want to delete: ";
#             cin >> choice;
#         } while (validateInput(choice, 1, customerCart.getAmount()));
#     }
#     else {
#         cout << endl;
#         cout << "ERROR: Your cart is empty. You must have an item in your cart to delete!" << endl;
#     }
#     return choice;
# }
#
# // Display and confirm whether the user wants to exit the program and return true to exit the program and vice-versa
# bool View::exitConfirmation() {
#     string isExit;
#     cout << endl;
#     cout << "Press Y/y to exit program: ";
#     cin >> isExit;
#     cin.ignore(MAX_STREAM_SIZE, '\n');
#     if (isExit == "Y" || isExit == "y") {
#         return true;
#     }
#     return false;
# }
# Out:
# Overwriting View.cpp

# %%
# %%writefile Inventory.cpp
# #include "Inventory.h"
# #include <iostream>
# #include <fstream>
# using namespace std;
#
# Inventory::Inventory() {
#     pastryList = nullptr;
#     read();
# }
#
# Inventory :: ~Inventory() {
#     delete[] pastryList;
# }
#
# void Inventory::read() {
#     delete[] pastryList;
#     // Read inventory.txt to get the number of items
#     fstream inventoryList("inventory.txt", ios::in);
#     string line;
#     // Initialize as -1 to ignore the header of inventory.txt and count from 0
#     int totalItemNumber = -1;
#     // inventoryList will read inventory.txt to store inside line
#     while (getline(inventoryList, line)) {
#         totalItemNumber++;
#     }
#     inventoryList.close();
#     totalItemNo = totalItemNumber;
#     pastryList = new Pastry[totalItemNo];
#     // Read inventory.txt to get and store type, flavour, piece...
#     inventoryList.open("inventory.txt", ios::in);
#     storeInfo(inventoryList, pastryList, totalItemNo);
#     inventoryList.close();
# }
#
# // The getPastryList method returns a pointer to the array of Pastry objects representing the inventory
# Pastry* Inventory::getPastryList() const {
#     return pastryList;
# }
#
# // The getItemNumber method returns the number of items in the pastry
# int Inventory::getItemNumber() const {
#     return totalItemNo;
# }
#
# // A boolean method to determine whether the inventory is empty
# bool Inventory::checkAllEmpty() const {
#     for (int i = 0; i < totalItemNo; i++) {
#         if (pastryList[i].getPiece() > 0) {
#             return false;
#         }
#     }
#     return true;
# }
#
# // The addLocalInventory method updates the quantity of a specific pastry item in the inventory
# void Inventory::addLocalInventory(Pastry pastryToChange) {
#     for (int i = 0; i < totalItemNo; i++) {
#         if (pastryList[i] == pastryToChange) {
#             // If the pastry item is found in the inventory, increment its quantity
#             // Using the overloaded operator
#             pastryList[i] += pastryToChange;
#             return;
#         }
#     }
# }
#
#
# // First update to write the inventory by reading the data from inventory.txt
# void Inventory::write() {
#     fstream inventoryList("inventory.txt", ios::trunc | ios::out);
#     writeInfo(inventoryList, pastryList, totalItemNo);
#     inventoryList.close();
# }
#
# bool Inventory::addPastryList(Pastry& newPastry) {
#     // If items of newPastry has overlap with items of pastryList, return false
#     for (int i = 0; i < totalItemNo; i++) {
#         if (pastryList[i] == newPastry) {
#             return false;
#         }
#     }
#     totalItemNo++;
#     // Create a newList to store items of pastryList and item of newPastry
#     Pastry* newList=new Pastry[totalItemNo];
#     for (int i = 0; i < (totalItemNo-1); i++) {
#         newList[i] = pastryList[i];
#     }
#     // Assign the new items inside newList
#     newList[totalItemNo-1] = newPastry;
#     delete[] pastryList;
#     // Assign address of newList into pastryList
#     pastryList = newList;
#     return true;
# }
# Out:
# Overwriting Inventory.cpp

# %%
# %%writefile Cart.cpp
# #include "Cart.h"
# #include <iostream>
# using namespace std;
#
# // Cart constructor
# Cart::Cart() {
#     inCartItem = nullptr;
#     amount = 0;
# }
#
# // Cart destructor
# Cart :: ~Cart() {
#     delete[] inCartItem;
#     amount = 0;
# }
#
# void Cart::addToCart(Pastry newPastry) {
#     // Update the amount if pastry present in the cart
#     for (int i = 0; i < amount; i++) {
#         if (inCartItem[i] == newPastry) {
#             inCartItem[i] += newPastry;
#             return;
#         }
#     }
#     // Correct size after user add to cart
#     amount++;
#     // Adding new item into cart by creating a temp to store the choice of user input for cookie or cake
#     Pastry* temp = new Pastry[amount];
#     for (int i = 0; i < amount - 1; i++) {
#         temp[i] = inCartItem[i];
#     }
#     // Assign the new choice inside temp
#     temp[amount - 1] = newPastry;
#     delete[] inCartItem;
#     // Assign address of temp into inCartItem
#     inCartItem = temp;
# }
#
# void Cart::deleteFromCart(int userInput) {
#     // Correct size after user delete from cart
#     amount--;
#     // Create a temp with the correct size after user delete from cart
#     Pastry* temp = new Pastry[amount];
#     // Assign the item before the deleted item into temp
#     for (int i = 0; i < userInput - 1; i++) {
#         temp[i] = inCartItem[i];
#     }
#     // Assign the item after the deleted item into temp
#     for (int i = userInput - 1; i < amount; i++) {
#         temp[i] = inCartItem[i + 1];
#     }
#     delete[] inCartItem;
#     // Assign address of temp into inCartItem
#     inCartItem = temp;
# }
#
# Pastry* Cart::getInCartItem() const {
#     return inCartItem;
# }
#
# float Cart::getTotalPrice(int discount, bool& gotDiscount) const {
#     float total=0;
#     for (int i = 0; i < amount; i++) {
#         total += inCartItem[i].getPrice();
#     }
#     if (discount % 5 == 0) {
#         gotDiscount = true;
#         return total * 0.9;
#     }
#     return total;
# }
# Out:
# Overwriting Cart.cpp

# %%
# %%writefile Pastry.cpp
# #include "Pastry.h"
# #include <iostream>
# using namespace std;
#
# //Pastry Constructor
# Pastry::Pastry() {}
#
# //Pastry Destructor
# Pastry :: ~Pastry(){};
#
# //Friend function for storing info of pastry that located in an arrray
# void storeInfo(fstream& inventoryList, Pastry* pastryList, int totalItemNo) {
#     string header;
#     // To ignore the header of inventoryList and store inside header
#     getline(inventoryList, header);
#     for (int i = 0; i < totalItemNo; i++) {
#         inventoryList >> pastryList[i].type
#             >> pastryList[i].flavour
#             >> pastryList[i].piece
#             >> pastryList[i].weight
#             >> pastryList[i].weightperpiece
#             >> pastryList[i].priceperweight;
#     }
# }
#
# //Friend function for write and update the txt file used to saved pastry info
# void writeInfo(fstream& inventoryList, Pastry* pastryList, int totalItemNo) {
#     inventoryList << "Type Flavour Piece Weight WeightPerPiece PricePerWeight" << endl;
#     for (int i = 0; i < totalItemNo; i++) {
#         inventoryList << pastryList[i].type << " "
#             << pastryList[i].flavour << " "
#             << pastryList[i].piece << " "
#             << pastryList[i].weight << " "
#             << pastryList[i].weightperpiece << " "
#             << pastryList[i].priceperweight << endl;
#     }
# }
#
#
# void Pastry::setType(string t) {
#     type = t;
# }
#
# void Pastry::setFlavour(string f) {
#     flavour = f;
# }
#
# void Pastry::setWPP(float wpp) {
#     weightperpiece = wpp;
# }
#
# void Pastry::setPPW(float ppw) {
#     priceperweight = ppw;
# }
#
# void Pastry::setPiece(float p) {
#     piece = p;
#     if (piece == 0.0) {
#         weight = 0.0;
#     }
#     else {
#         weight = p * weightperpiece;
#     }
# }
#
# void Pastry::setWeight(float w) {
#     weight = w;
#     if (weight == 0.0) {
#         piece = 0.0;
#     }
#     else {
#         piece = w / weightperpiece;
#     }
# }
#
# //Set value of pastry when adding new item
# void Pastry::setPastryValue(string t, string f, float wpp, float ppw, float p, float w) {
#     type = t;
#     flavour = f;
#     weightperpiece = wpp;
#     priceperweight = ppw;
#     piece = p;
#     weight = w;
# }
#
# //- Operator overloading to decrease weight, piece of pastry for cart and inventory operations
# Pastry& Pastry :: operator-=(const Pastry& changes) {
#     piece -= changes.piece;
#     weight -= changes.weight;
#     if (piece == 0.0 || weight == 0.0) {
#         weight = 0.0;
#         piece = 0.0;
#     }
#     return *this;
# }
#
# //+ Operator overloading to increase weight, piece of pastry for cart and inventory operations
# Pastry& Pastry :: operator+=(const Pastry& changes) {
#     piece += changes.piece;
#     weight += changes.weight;
#     if (piece == 0.0 || weight == 0.0) {
#         weight = 0.0;
#         piece = 0.0;
#     }
#     return *this;
# }
#
# //= Operator overloading to compare type and name of pastry
# bool Pastry :: operator==(const Pastry& other) {
#     return (type == other.type && flavour == other.flavour);
# }
# Out:
# Overwriting Pastry.cpp

# %% [markdown]
# ###Main file

# %%
# %%writefile main.cpp
# #include <iostream>
# #include "Shop.h"
# using namespace std;
#
# // The main function is the entry point of the program.
# // It creates an instance of the Shop class and calls its main method,
# // which handles the user interactions and controls the overall flow of the program.
# int main(){
#     Shop shop; // Create an instance of the Shop class
#     shop.main(); // Call the main method of the Shop class
#     return 0;
# }
# Out:
# Overwriting main.cpp

# %% [markdown]
# ##Test Cases

# %% [markdown]
# First Scenario : User Log in or Sign Up
#
# Scenario 1: User log in as either staff or customer successfully
#
# User log in as staff or customer, choose to log in, enter username and password and the system match the input data with the input file's username and password.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# cc1plus: fatal error: *.cpp: No such file or directory
# compilation terminated.
# /bin/bash: line 2: ./main.exe: No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-1-59d9ad398934> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('shell', '', 'g++ *.cpp -o main.exe\n./main.exe\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
# ...

# %% [markdown]
# Scenario 2: User sign up as either staff or customer successfully
#
# User sign up as staff or customer, choose to sign up, enter username and password and the system updates input file.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# -----------------------------------------------------
# |      Welcome to My Eid Cookies and Cakes Hub       |
# -----------------------------------------------------
# | Please enter (0-2):                                |
# | 0. Exit                                            |
# | 1. Staff                                           |
# | 2. Customer                                        |
# -----------------------------------------------------
# Your choice: 2
#
# -----------------------------------------------------
# |                   Login / SignUp                   |
# -----------------------------------------------------
# | Please enter (1-3):                                |
# | 1. Login                                           |
# | 2. Signup                                          |
# | 3. Back to Choose Role                             |
# -----------------------------------------------------
# Your choice: 2
#
# -----------------------------------------------------
# ...

# %% [markdown]
# Scenario 3: User log in as either staff or customer by entering wrong username or password
#
# In this scenario, the input data does not match the input file's username and password. The system communicates the unavailability of log in to the user, who then decides to log in or sign up again.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# -----------------------------------------------------
# |      Welcome to My Eid Cookies and Cakes Hub       |
# -----------------------------------------------------
# | Please enter (0-2):                                |
# | 0. Exit                                            |
# | 1. Staff                                           |
# | 2. Customer                                        |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# |                   Login / SignUp                   |
# -----------------------------------------------------
# | Please enter (1-3):                                |
# | 1. Login                                           |
# | 2. Signup                                          |
# | 3. Back to Choose Role                             |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# ...

# %% [markdown]
# Scenario 4: Users can sign up as either staff or customers by entering a username and password that have been previously registered
#
# In this scenario, the input data match with the input file's username and password. The system communicates the unavailability of sign up to the user, who then decides to log in or sign up again.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# -----------------------------------------------------
# |      Welcome to My Eid Cookies and Cakes Hub       |
# -----------------------------------------------------
# | Please enter (0-2):                                |
# | 0. Exit                                            |
# | 1. Staff                                           |
# | 2. Customer                                        |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# |                   Login / SignUp                   |
# -----------------------------------------------------
# | Please enter (1-3):                                |
# | 1. Login                                           |
# | 2. Signup                                          |
# | 3. Back to Choose Role                             |
# -----------------------------------------------------
# Your choice: 2
#
# -----------------------------------------------------
# ...

# %% [markdown]
# Second Scenario : Staff Operations Menu
#
# Scenario 1: Users check inventory
#
# User check inventory, output file will display current stock.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# -----------------------------------------------------
# |      Welcome to My Eid Cookies and Cakes Hub       |
# -----------------------------------------------------
# | Please enter (0-2):                                |
# | 0. Exit                                            |
# | 1. Staff                                           |
# | 2. Customer                                        |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# |                   Login / SignUp                   |
# -----------------------------------------------------
# | Please enter (1-3):                                |
# | 1. Login                                           |
# | 2. Signup                                          |
# | 3. Back to Choose Role                             |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# ...

# %% [markdown]
# Scenario 2: Users edit inventory successfully
#
# User edit inventory, choose the item that want to edit, choose to edit its type, flavour, piece, weight or price per weight, edit with the correct datas and the system updates inventory.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# -----------------------------------------------------
# |      Welcome to My Eid Cookies and Cakes Hub       |
# -----------------------------------------------------
# | Please enter (0-2):                                |
# | 0. Exit                                            |
# | 1. Staff                                           |
# | 2. Customer                                        |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# |                   Login / SignUp                   |
# -----------------------------------------------------
# | Please enter (1-3):                                |
# | 1. Login                                           |
# | 2. Signup                                          |
# | 3. Back to Choose Role                             |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# ...

# %% [markdown]
# Scenario 3: Users edit inventory by entering invalid datas (etc. Type)
#
# In this scenario, the system communicates the invalidation of input to the user, who then need to edit the item's type again and updates inventory.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# -----------------------------------------------------
# |      Welcome to My Eid Cookies and Cakes Hub       |
# -----------------------------------------------------
# | Please enter (0-2):                                |
# | 0. Exit                                            |
# | 1. Staff                                           |
# | 2. Customer                                        |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# |                   Login / SignUp                   |
# -----------------------------------------------------
# | Please enter (1-3):                                |
# | 1. Login                                           |
# | 2. Signup                                          |
# | 3. Back to Choose Role                             |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# ...

# %% [markdown]
# Scenario 4: Users add new item successfully
#
# User add new item to the inventory, enter information of new item such as type, flavour, piece, weight per piece and price per weight.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# -----------------------------------------------------
# |      Welcome to My Eid Cookies and Cakes Hub       |
# -----------------------------------------------------
# | Please enter (0-2):                                |
# | 0. Exit                                            |
# | 1. Staff                                           |
# | 2. Customer                                        |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# |                   Login / SignUp                   |
# -----------------------------------------------------
# | Please enter (1-3):                                |
# | 1. Login                                           |
# | 2. Signup                                          |
# | 3. Back to Choose Role                             |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# ...

# %% [markdown]
# Fourth Scenario: Customer places an order
#
# Scenario 1: Successful Order Placement
#
# The user adds items by piece or weight to the cart, proceeds to payment, and confirms the order and the system updates inventory.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# -----------------------------------------------------
# |      Welcome to My Eid Cookies and Cakes Hub       |
# -----------------------------------------------------
# | Please enter (0-2):                                |
# | 0. Exit                                            |
# | 1. Staff                                           |
# | 2. Customer                                        |
# -----------------------------------------------------
# Your choice: 2
#
# -----------------------------------------------------
# |                   Login / SignUp                   |
# -----------------------------------------------------
# | Please enter (1-3):                                |
# | 1. Login                                           |
# | 2. Signup                                          |
# | 3. Back to Choose Role                             |
# -----------------------------------------------------
# Your choice: 2
#
# -----------------------------------------------------
# ...

# %% [markdown]
# Scenario 2: Order with Promotion
#
# Additional interactions with the Discount Service are depicted, showing how the discount code affects the order total.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# -----------------------------------------------------
# |      Welcome to My Eid Cookies and Cakes Hub       |
# -----------------------------------------------------
# | Please enter (0-2):                                |
# | 0. Exit                                            |
# | 1. Staff                                           |
# | 2. Customer                                        |
# -----------------------------------------------------
# Your choice: 2
#
# -----------------------------------------------------
# |                   Login / SignUp                   |
# -----------------------------------------------------
# | Please enter (1-3):                                |
# | 1. Login                                           |
# | 2. Signup                                          |
# | 3. Back to Choose Role                             |
# -----------------------------------------------------
# Your choice: 2
#
# -----------------------------------------------------
# ...

# %% [markdown]
# Scenario 3: Order with Out-of-Stock Items
#
# In this scenario, the Inventory System communicates the unavailability of an item to the user, who then decides to replace the item.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# -----------------------------------------------------
# |      Welcome to My Eid Cookies and Cakes Hub       |
# -----------------------------------------------------
# | Please enter (0-2):                                |
# | 0. Exit                                            |
# | 1. Staff                                           |
# | 2. Customer                                        |
# -----------------------------------------------------
# Your choice: 2
#
# -----------------------------------------------------
# |                   Login / SignUp                   |
# -----------------------------------------------------
# | Please enter (1-3):                                |
# | 1. Login                                           |
# | 2. Signup                                          |
# | 3. Back to Choose Role                             |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# ...

# %% [markdown]
# Scenario 4: Choose Wrong Items
#
# In this scenario, user remove the item by themselves and updates inventory.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# -----------------------------------------------------
# |      Welcome to My Eid Cookies and Cakes Hub       |
# -----------------------------------------------------
# | Please enter (0-2):                                |
# | 0. Exit                                            |
# | 1. Staff                                           |
# | 2. Customer                                        |
# -----------------------------------------------------
# Your choice: 2
#
# -----------------------------------------------------
# |                   Login / SignUp                   |
# -----------------------------------------------------
# | Please enter (1-3):                                |
# | 1. Login                                           |
# | 2. Signup                                          |
# | 3. Back to Choose Role                             |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# ...

# %% [markdown]
# Scenario 5: Place an order without immediate payment
#
# In this scenario, user chooses not to proceed with payment yet, but the items in the cart remain.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# -----------------------------------------------------
# |      Welcome to My Eid Cookies and Cakes Hub       |
# -----------------------------------------------------
# | Please enter (0-2):                                |
# | 0. Exit                                            |
# | 1. Staff                                           |
# | 2. Customer                                        |
# -----------------------------------------------------
# Your choice: 2
#
# -----------------------------------------------------
# |                   Login / SignUp                   |
# -----------------------------------------------------
# | Please enter (1-3):                                |
# | 1. Login                                           |
# | 2. Signup                                          |
# | 3. Back to Choose Role                             |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# ...

# %% [markdown]
# Scenario 5: Does not place order but proceed to payment
#
# In this scenario, the Inventory System communicates the unavailability of an item to the user, who then decides to add the item into the cart.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# -----------------------------------------------------
# |      Welcome to My Eid Cookies and Cakes Hub       |
# -----------------------------------------------------
# | Please enter (0-2):                                |
# | 0. Exit                                            |
# | 1. Staff                                           |
# | 2. Customer                                        |
# -----------------------------------------------------
# Your choice: 2
#
# -----------------------------------------------------
# |                   Login / SignUp                   |
# -----------------------------------------------------
# | Please enter (1-3):                                |
# | 1. Login                                           |
# | 2. Signup                                          |
# | 3. Back to Choose Role                             |
# -----------------------------------------------------
# Your choice: 1
#
# -----------------------------------------------------
# ...
